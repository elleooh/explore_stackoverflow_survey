# %% [markdown]
# # Project Goal/Business Understanding

# %% [markdown]
# This project aims to draw some compelling (and hopefully not stereotypical) personality profiles of programmers, particularly professional developers based in the US.
#
# This notebook focuses on one particular personality trait - <b>competitiveness</b>.
#
# Below are the questions we are going to answer through the lens of this project:
#
# - Do more or fewer programmers think they are competing with their peers?
# - What factors might be associated with people’s competitiveness?
# 	- Does gender matter?
# 	- Does race matter?
# 	- Do the years of coding experience on the job matter?
# 	- Does the type of developer matter?
# 	- Does the type or the size of the company people work for matter?
# - Are competitive programmers tend to be satisfied with their jobs or not?

# %% [markdown]
# # Data Understanding

# %% [markdown]
# The 2017 Stack Overflow Developer Survery asked many interesting questions related to personality type. <br>
#
# For the purpose of this study, we are particularly interested in  people's response to the below survey question on competitiveness - <br>
#
# <i><b>"I think of myself as competing with my peers"</b></i>

# %% [markdown]
# # Prepare Data

# %%
import pandas as pd
import statsmodels.api as sm

# %%
import Modules.utilities as u
import Modules.clean_data_frame as cd
import Modules.create_comp_table as ct
import Modules.inferential_statistics as s

# %%
survey17 = pd.read_csv('./Data/survey_results_public_2017.csv')

# %% [markdown]
# People’s perceptions of personality are largely dependent on culture and their current state of life. So to compare apples to apples, we are only going to look at US respondents who are also professional developers. We ended up with about 3,300 respondents.

# %%
surveyFiltered = survey17.loc[(survey17['Country'] == 'United States') \
                              & (survey17['Professional'] == 'Professional developer')]

# %%
print('We have {} respondents left for our analysis.'.format(surveyFiltered.shape[0]))
# Out:
# We have 3230 respondents left for our analysis.

# %% [markdown]
# There are four types of responses for those questions mentioned above: “Agree”, “Somewhat agree”, “Disagree”, and “Strongly disagree”. <br>
#
# I grouped those responses into two buckets: “Agree” and “Disagree” before performing statistical tests to ensure that we have enough data in each bucket to meet the condition for performing those statistical tests.

# %%
res = 'CompetePeers_bin'

# For easy comparison and calculation, put survey response into agree (1) and disagree (0)
surveyFiltered = cd.binarize_col(surveyFiltered, 'CompetePeers', \
                                 ['Somewhat agree', 'Agree', 'Strongly agree'])

# %% [markdown]
# # Data Analysis and Modeling

# %% [markdown]
# <b>Methodology</b><br>
# For each question, I will perform the <b>Chi-Square Test for Independence </b>to compare whether the variable of interest (e.g. gender, race) had any relationship with competitiveness. <br>
#
# If the Chi-Square test showed a relationship between the variable and competitiveness, I will then perform <b> one proportion Z-test </b> for each group to see if within the group, whether the percentage of people who agreed with the statement was significantly higher or lower than 50% (random chance). <br>
#
# To answer the question 'Are competitive programmers tend to be satisfied with their jobs or not?', I will perform a simple <b>one-variable linear regression</b> of job satisfaction (on a scale of 0 to 10) against the competitiveness indicator.

# %% [markdown]
# ### Q0: How did people answer all personality survey questions?
# Let's first look at how people respond to all of the personality survey questions to get a general understanding.

# %%
traitLst = ['ProblemSolving', 'BuildingThings', 'LearningNewTech', 'ChallengeMyself', \
            'CompetePeers', 'BoringDetails', 'RightWrongWay']

# %%
## draw distribution of each trait
for trait in traitLst:
    u.draw_hist_cat(df = surveyFiltered, col = trait)

# %% [markdown]
# The result of 'Problem Solving', 'Building Things', 'Learning New Tech', and 'Challenge Myself' are not surprising. A large majority of respondents describe themselves as problem solver. Most of the respondents also like building things, learning new technologies. and challenging themselves. Very much align with the typical developer personality profile :) <br>
#
# 'CompetePeers', 'Boring Details', and 'RightWrongWay' and  results are a lot more interesting, as almost half and half people agree and disagree with the statement. <br>
#
# This notebook will take a deep dive into 'CompetePeers'.

# %% [markdown]
# ### Q1: Does feeling more or less competitive depends on gender?

# %%
feature = 'Gender'

# clean and create a new df based on feature of interest
gender_df = cd.clean_df(surveyFiltered, feature)

# %%
# perform chi-square test for independence
s.print_chi2_test_result(gender_df, feature, res, ['agree', 'disagree'])
# Out:
# The p_value for chi-square test for independence between Gender and CompetePeers_bin is 0.16

# %% [markdown]
# The p-value is quite large. Under the significance level of 0.05, we are not able to reject the null hypothesis that gender and competitiveness are independent.

# %% [markdown]
# ### Q2: Does feeling more or less competitive depends on race?

# %%
feature = 'Race'

# clean and create a new df based on feature of interest
race_df = cd.clean_df(surveyFiltered, feature)

# %%
# perform chi-square test for independence
s.print_chi2_test_result(race_df, feature, res, ['agree', 'disagree'])
# Out:
# The p_value for chi-square test for independence between Race and CompetePeers_bin is 0.01

# %% [markdown]
# Since the p-value is less than the significance level (0.05), we reject the null hypothesis and conclude that there is a relationship between Race and CompetePeers. Let's dig deeper!

# %%
ct.plot_comp_table(race_df, feature, res, rank_order_lst=None)
# Out:
# <style  type="text/css" >
#     #T_88a6698a_391b_11eb_b648_cd871c33cf75row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }    #T_88a6698a_391b_11eb_b648_cd871c33cf75row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.4%, #5fba7d 19.4%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_88a6698a_391b_11eb_b648_cd871c33cf75row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.4%, #5fba7d 19.4%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_88a6698a_391b_11eb_b648_cd871c33cf75row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.4%, #5fba7d 19.4%, #5fba7d 77.8%, transparent 77.8%);
#         }    #T_88a6698a_391b_11eb_b648_cd871c33cf75row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.4%, #5fba7d 19.4%, #5fba7d 66.7%, transparent 66.7%);
#         }</style><table id="T_88a6698a_391b_11eb_b648_cd871c33cf75" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >value</th>        <th class="col_heading level0 col1" >total count</th>        <th class="col_heading level0 col2" >agree %</th>        <th class="col_heading level0 col3" >disagree %</th>        <th class="col_heading level0 col4" >difference %</th>        <th class="col_heading level0 col5" >significant?</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88a6698a_391b_11eb_b648_cd871c33cf75level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row0_col0" class="data row0 col0" >White or of European descent</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row0_col1" class="data row0 col1" >1515</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row0_col2" class="data row0 col2" >0.47</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row0_col3" class="data row0 col3" >0.53</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row0_col4" class="data row0 col4" >-0.07</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row0_col5" class="data row0 col5" >yes</td>
#             </tr>
#             <tr>
#                         <th id="T_88a6698a_391b_11eb_b648_cd871c33cf75level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row1_col0" class="data row1 col0" >East Asian</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row1_col1" class="data row1 col1" >79</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row1_col2" class="data row1 col2" >0.56</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row1_col3" class="data row1 col3" >0.44</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row1_col4" class="data row1 col4" >0.11</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row1_col5" class="data row1 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_88a6698a_391b_11eb_b648_cd871c33cf75level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row2_col0" class="data row2 col0" >South Asian</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row2_col1" class="data row2 col1" >56</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row2_col2" class="data row2 col2" >0.64</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row2_col3" class="data row2 col3" >0.36</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row2_col4" class="data row2 col4" >0.29</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row2_col5" class="data row2 col5" >yes</td>
#             </tr>
#             <tr>
#                         <th id="T_88a6698a_391b_11eb_b648_cd871c33cf75level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row3_col0" class="data row3 col0" >I prefer not to say</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row3_col1" class="data row3 col1" >43</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row3_col2" class="data row3 col2" >0.6</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row3_col3" class="data row3 col3" >0.4</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row3_col4" class="data row3 col4" >0.21</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row3_col5" class="data row3 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_88a6698a_391b_11eb_b648_cd871c33cf75level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row4_col0" class="data row4 col0" >Hispanic or Latino/Latina</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row4_col1" class="data row4 col1" >41</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row4_col2" class="data row4 col2" >0.59</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row4_col3" class="data row4 col3" >0.41</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row4_col4" class="data row4 col4" >0.17</td>
#                         <td id="T_88a6698a_391b_11eb_b648_cd871c33cf75row4_col5" class="data row4 col5" >no</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Based on only the statistically significant results, White or of European descent tend to feel less competitive against their peers. Whereas, South Asian tend to feel a lot competitive against their peers.

# %% [markdown]
# ### Q3: Do you feel more or less competitive as your years of coding experience increase?

# %%
feature = 'YearsCodedJob'

# %%
# The original dataset has each incremental year of experience as a bucket, which might be too granular to provide much value.
# Instead, bucket every 5 years of coding exeprience into one.
yearsCodedJob_mapping = {
    'Less than a year': '0-5 years',
    '1 to 2 years': '0-5 years',
    '2 to 3 years': '0-5 years',
    '3 to 4 years': '0-5 years',
    '4 to 5 years': '0-5 years',
    '5 to 6 years': '5-10 years',
    '6 to 7 years': '5-10 years',
    '7 to 8 years': '5-10 years',
    '8 to 9 years': '5-10 years',
    '9 to 10 years': '5-10 years',
    '10 to 11 years': '10-15 years',
    '11 to 12 years': '10-15 years',
    '12 to 13 years': '10-15 years',
    '13 to 14 years': '10-15 years',
    '14 to 15 years': '10-15 years',
    '15 to 16 years': '15-20 years',
    '16 to 17 years': '15-20 years',
    '17 to 18 years': '15-20 years',
    '18 to 19 years': '15-20 years',
    '19 to 20 years': '15-20 years',
    '20 or more years': '20 or more years'
}

# %%
yearsCodedJob_df = surveyFiltered.dropna(subset =[feature], axis=0)
yearsCodedJob_df.loc[:, feature] = yearsCodedJob_df[feature].apply(lambda col: \
                                                                   yearsCodedJob_mapping[col])

# %%
# perform chi-square test for independence
s.print_chi2_test_result(yearsCodedJob_df, feature, res, ['agree', 'disagree'])
# Out:
# The p_value for chi-square test for independence between YearsCodedJob and CompetePeers_bin is 0.00

# %% [markdown]
# Since the p-value is less than the significance level (0.05), we reject the null hypothesis and conclude that there is a relationship between YearsCodedJob and CompetePeers. <br>
#
# Let's take a deeper look into what does the relationship look like -

# %%
yearsCodedJob_lst = ['0-5 years','5-10 years','10-15 years', '15-20 years', '20 or more years']
ct.plot_comp_table(yearsCodedJob_df, feature, res, rank_order_lst=yearsCodedJob_lst)
# Out:
# <style  type="text/css" >
#     #T_920291b6_391b_11eb_b648_cd871c33cf75row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 62.1%, #5fba7d 62.1%, #5fba7d 89.7%, transparent 89.7%);
#         }    #T_920291b6_391b_11eb_b648_cd871c33cf75row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.2%, #d65f5f 55.2%, #d65f5f 62.1%, transparent 62.1%);
#         }    #T_920291b6_391b_11eb_b648_cd871c33cf75row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 62.1%, #5fba7d 62.1%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_920291b6_391b_11eb_b648_cd871c33cf75row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 24.1%, #d65f5f 24.1%, #d65f5f 62.1%, transparent 62.1%);
#         }    #T_920291b6_391b_11eb_b648_cd871c33cf75row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 62.1%, transparent 62.1%);
#         }</style><table id="T_920291b6_391b_11eb_b648_cd871c33cf75" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >value</th>        <th class="col_heading level0 col1" >total count</th>        <th class="col_heading level0 col2" >agree %</th>        <th class="col_heading level0 col3" >disagree %</th>        <th class="col_heading level0 col4" >difference %</th>        <th class="col_heading level0 col5" >significant?</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_920291b6_391b_11eb_b648_cd871c33cf75level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row0_col0" class="data row0 col0" >0-5 years</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row0_col1" class="data row0 col1" >812</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row0_col2" class="data row0 col2" >0.54</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row0_col3" class="data row0 col3" >0.46</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row0_col4" class="data row0 col4" >0.08</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row0_col5" class="data row0 col5" >yes</td>
#             </tr>
#             <tr>
#                         <th id="T_920291b6_391b_11eb_b648_cd871c33cf75level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row1_col0" class="data row1 col0" >5-10 years</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row1_col1" class="data row1 col1" >526</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row1_col2" class="data row1 col2" >0.49</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row1_col3" class="data row1 col3" >0.51</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row1_col4" class="data row1 col4" >-0.02</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row1_col5" class="data row1 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_920291b6_391b_11eb_b648_cd871c33cf75level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row2_col0" class="data row2 col0" >10-15 years</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row2_col1" class="data row2 col1" >304</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row2_col2" class="data row2 col2" >0.56</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row2_col3" class="data row2 col3" >0.44</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row2_col4" class="data row2 col4" >0.11</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row2_col5" class="data row2 col5" >yes</td>
#             </tr>
#             <tr>
#                         <th id="T_920291b6_391b_11eb_b648_cd871c33cf75level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row3_col0" class="data row3 col0" >15-20 years</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row3_col1" class="data row3 col1" >207</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row3_col2" class="data row3 col2" >0.44</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row3_col3" class="data row3 col3" >0.56</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row3_col4" class="data row3 col4" >-0.11</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row3_col5" class="data row3 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_920291b6_391b_11eb_b648_cd871c33cf75level0_row4" class="row_heading level0 row4" >3</th>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row4_col0" class="data row4 col0" >20 or more years</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row4_col1" class="data row4 col1" >367</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row4_col2" class="data row4 col2" >0.41</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row4_col3" class="data row4 col3" >0.59</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row4_col4" class="data row4 col4" >-0.18</td>
#                         <td id="T_920291b6_391b_11eb_b648_cd871c33cf75row4_col5" class="data row4 col5" >yes</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Let's only look at results that are statistically significant - <br>
#
# Somewhat expected, folks with less than 5 years of coding experience tend to feel a lot more competitive against their peers compared to the rest of the coding experience group.<br>
#
# Folks with 10-15 years of experience become more competitive. Maybe because 10-15 years is around the time people are competing to become staff engineer/manager? <br>
#
# Respondents with more than 20 years of experience are a lot less competitive against their peers. At this point, really, you've finally reached the point where you can competite only with yourself. <br>

# %% [markdown]
# ### Q4: Do respondents of certain developer types tend to be more competitive?

# %%
feature = 'DeveloperTypeCombined'

# clean 'DeveloperTypeCombined'
## 1.combine all different types of developer types entries into one column
## 2.retrieve more granular developer type since more than 70% of the respondents put 'web developer' as their developer type
## 3.assign 'QA engineers' to 'Other' type since there are only two of them
## 4.assign 'Developer with a statistics or mathematics background' as 'Data scientist', since most of them indicated themselves also as 'Data scientist'

devTypes_lst = ['DeveloperType', 'WebDeveloperType', 'MobileDeveloperType', 'NonDeveloperType']
devTypes_df = cd.clean_dev_type(surveyFiltered, feature, devTypes_lst)

# %%
# perform chi-square test for independence
s.print_chi2_test_result(devTypes_df, feature, res, ['agree', 'disagree'])
# Out:
# The p_value for chi-square test for independence between DeveloperTypeCombined and CompetePeers_bin is 0.08

# %% [markdown]
# Under the significance level of 0.05, we are not able to reject the null hypothesis under the significance level. <br>
#
# However, since the p-value is only slightly higher than the significance level, it might still worth of time to look into the competitiveness under different DeveloperTypes.

# %%
ct.plot_comp_table(devTypes_df, feature, res, rank_order_lst=None)
# Out:
# <style  type="text/css" >
#     #T_98f81040_391b_11eb_b648_cd871c33cf75row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.9%, #5fba7d 55.9%, #5fba7d 61.0%, transparent 61.0%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.9%, #5fba7d 55.9%, #5fba7d 67.8%, transparent 67.8%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row2_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.9%, #5fba7d 55.9%, #5fba7d 61.0%, transparent 61.0%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.2%, #d65f5f 32.2%, #d65f5f 55.9%, transparent 55.9%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.0%, #d65f5f 39.0%, #d65f5f 55.9%, transparent 55.9%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.9%, #5fba7d 55.9%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.5%, #d65f5f 30.5%, #d65f5f 55.9%, transparent 55.9%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.9%, #5fba7d 55.9%, #5fba7d 71.2%, transparent 71.2%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.5%, #d65f5f 47.5%, #d65f5f 55.9%, transparent 55.9%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 52.5%, #d65f5f 52.5%, #d65f5f 55.9%, transparent 55.9%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row11_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.9%, #5fba7d 55.9%, #5fba7d 69.5%, transparent 69.5%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row12_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 55.9%, transparent 55.9%);
#         }    #T_98f81040_391b_11eb_b648_cd871c33cf75row13_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.9%, #d65f5f 33.9%, #d65f5f 55.9%, transparent 55.9%);
#         }</style><table id="T_98f81040_391b_11eb_b648_cd871c33cf75" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >value</th>        <th class="col_heading level0 col1" >total count</th>        <th class="col_heading level0 col2" >agree %</th>        <th class="col_heading level0 col3" >disagree %</th>        <th class="col_heading level0 col4" >difference %</th>        <th class="col_heading level0 col5" >significant?</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_98f81040_391b_11eb_b648_cd871c33cf75level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row0_col0" class="data row0 col0" >Full stack Web developer</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row0_col1" class="data row0 col1" >502</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row0_col2" class="data row0 col2" >0.51</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row0_col3" class="data row0 col3" >0.49</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row0_col4" class="data row0 col4" >0.03</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row0_col5" class="data row0 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_98f81040_391b_11eb_b648_cd871c33cf75level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row1_col0" class="data row1 col0" >Mobile developer</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row1_col1" class="data row1 col1" >368</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row1_col2" class="data row1 col2" >0.53</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row1_col3" class="data row1 col3" >0.47</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row1_col4" class="data row1 col4" >0.07</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row1_col5" class="data row1 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_98f81040_391b_11eb_b648_cd871c33cf75level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row2_col0" class="data row2 col0" >Desktop applications developer</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row2_col1" class="data row2 col1" >334</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row2_col2" class="data row2 col2" >0.5</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row2_col3" class="data row2 col3" >0.5</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row2_col5" class="data row2 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_98f81040_391b_11eb_b648_cd871c33cf75level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row3_col0" class="data row3 col0" >Data scientist</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row3_col1" class="data row3 col1" >181</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row3_col2" class="data row3 col2" >0.51</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row3_col3" class="data row3 col3" >0.49</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row3_col4" class="data row3 col4" >0.03</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row3_col5" class="data row3 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_98f81040_391b_11eb_b648_cd871c33cf75level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row4_col0" class="data row4 col0" >Embedded applications/devices developer</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row4_col1" class="data row4 col1" >155</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row4_col2" class="data row4 col2" >0.43</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row4_col3" class="data row4 col3" >0.57</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row4_col4" class="data row4 col4" >-0.14</td>
#                         <td id="T_98f81040_391b_11eb_b648_cd871c33cf75row4_col5" class="data row4 col5" >yes</td>
#             </tr>
#             <tr>

# %% [markdown]
# A significantly larger share of DevOps specialists think they are competing with their peers compared to developers of other developer types. In fact, embedded applications/devices developers and graphics programming developers are much less likely to think they are competiting with their peers.

# %% [markdown]
# ### Q5: Do you feel more or less competitive in a small company or in a large company

# %%
feature = 'CompanySize'

# clean 'CompanySize'
## 1.drop rows where entry is NA
## 2.drop rows where the response is 'I prefer not to answer' or "I don't know" 
companySize_df = cd.clean_df(surveyFiltered, feature, ['I prefer not to answer', "I don't know"])

# %%
# perform chi-square test for independence
s.print_chi2_test_result(companySize_df, feature, res, ['agree', 'disagree'])
# Out:
# The p_value for chi-square test for independence between CompanySize and CompetePeers_bin is 0.46

# %% [markdown]
# The p-value is very large. Under the significance level of 0.05, we are not able to reject the null hypothesis that CompanySize and competitiveness are independent.

# %% [markdown]
# ### Q6: What about company type?

# %%
feature = 'CompanyType'
# clean 'CompanyType'
## 1.drop rows where entry is NA
## 2.drop rows where the response is 'I prefer not to answer' or "I don't know" 
companyType_df = cd.clean_df(surveyFiltered, feature, ['I prefer not to answer', "I don't know"])

# %%
# perform chi-square test for independence
s.print_chi2_test_result(companyType_df, feature, res, ['agree', 'disagree'])
# Out:
# The p_value for chi-square test for independence between CompanyType and CompetePeers_bin is 0.13

# %% [markdown]
# The p-value is quite large. Under the significance level of 0.05, we are not able to reject the null hypothesis that CompanyType and competitiveness are independent.

# %% [markdown]
# ### Q7: What about company type and size together?

# %%
companySizeType_df = cd.clean_df(companySize_df, 'CompanyType', \
                                 ['I prefer not to answer', "I don't know"])

# %%
feature = 'CompanySizeType'

companySizeType_df[feature] = \
companySizeType_df['CompanyType'] + ' (' + companySizeType_df['CompanySize'] + ')'

companySizeType_df = cd.clean_df(companySizeType_df, feature, \
                                 ['I prefer not to answer', "I don't know"])

# %%
# perform chi-square test for independence
s.print_chi2_test_result(companySizeType_df, feature, res, ['agree', 'disagree'])
# Out:
# The p_value for chi-square test for independence between CompanySizeType and CompetePeers_bin is 0.04

# %% [markdown]
# Since the p-value is less than the significance level (0.05), we reject the null hypothesis and conclude that there is a relationship between Company Size <b>and</b> Type and CompetePeers.

# %%
ct.plot_comp_table(companySizeType_df, feature, res)
# Out:
# <style  type="text/css" >
#     #T_ad140a34_391b_11eb_b648_cd871c33cf75row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.9%, #5fba7d 25.9%, #5fba7d 37.0%, transparent 37.0%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.9%, #5fba7d 25.9%, #5fba7d 32.1%, transparent 32.1%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.2%, #d65f5f 22.2%, #d65f5f 25.9%, transparent 25.9%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.8%, #d65f5f 14.8%, #d65f5f 25.9%, transparent 25.9%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.9%, #5fba7d 25.9%, #5fba7d 35.8%, transparent 35.8%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.9%, #5fba7d 25.9%, #5fba7d 51.9%, transparent 51.9%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 24.7%, #d65f5f 24.7%, #d65f5f 25.9%, transparent 25.9%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.9%, #5fba7d 25.9%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row9_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.5%, #d65f5f 23.5%, #d65f5f 25.9%, transparent 25.9%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row11_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.9%, #5fba7d 25.9%, #5fba7d 39.5%, transparent 39.5%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row12_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.9%, #5fba7d 25.9%, #5fba7d 38.3%, transparent 38.3%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row13_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.8%, #d65f5f 19.8%, #d65f5f 25.9%, transparent 25.9%);
#         }    #T_ad140a34_391b_11eb_b648_cd871c33cf75row14_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.5%, #d65f5f 18.5%, #d65f5f 25.9%, transparent 25.9%);
#         }</style><table id="T_ad140a34_391b_11eb_b648_cd871c33cf75" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >value</th>        <th class="col_heading level0 col1" >total count</th>        <th class="col_heading level0 col2" >agree %</th>        <th class="col_heading level0 col3" >disagree %</th>        <th class="col_heading level0 col4" >difference %</th>        <th class="col_heading level0 col5" >significant?</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ad140a34_391b_11eb_b648_cd871c33cf75level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row0_col0" class="data row0 col0" >Publicly-traded corporation (10,000 or more employees)</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row0_col1" class="data row0 col1" >323</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row0_col2" class="data row0 col2" >0.54</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row0_col3" class="data row0 col3" >0.46</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row0_col4" class="data row0 col4" >0.09</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row0_col5" class="data row0 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_ad140a34_391b_11eb_b648_cd871c33cf75level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row1_col0" class="data row1 col0" >Privately-held limited company, not in startup mode (100 to 499 employees)</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row1_col1" class="data row1 col1" >182</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row1_col2" class="data row1 col2" >0.53</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row1_col3" class="data row1 col3" >0.47</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row1_col4" class="data row1 col4" >0.05</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row1_col5" class="data row1 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_ad140a34_391b_11eb_b648_cd871c33cf75level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row2_col0" class="data row2 col0" >Privately-held limited company, not in startup mode (20 to 99 employees)</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row2_col1" class="data row2 col1" >177</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row2_col2" class="data row2 col2" >0.49</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row2_col3" class="data row2 col3" >0.51</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row2_col4" class="data row2 col4" >-0.03</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row2_col5" class="data row2 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_ad140a34_391b_11eb_b648_cd871c33cf75level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row3_col0" class="data row3 col0" >Publicly-traded corporation (1,000 to 4,999 employees)</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row3_col1" class="data row3 col1" >105</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row3_col2" class="data row3 col2" >0.46</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row3_col3" class="data row3 col3" >0.54</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row3_col4" class="data row3 col4" >-0.09</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row3_col5" class="data row3 col5" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_ad140a34_391b_11eb_b648_cd871c33cf75level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row4_col0" class="data row4 col0" >Privately-held limited company, not in startup mode (1,000 to 4,999 employees)</td>
#                         <td id="T_ad140a34_391b_11eb_b648_cd871c33cf75row4_col1" class="data row4 col1" >76</td>
#                         <td id="T_ad140a34_391b

# %% [markdown]
# The only two significant results are for Privately-held limited company with 10,000 or more employees and Venture-funded startup with 100 to 499 employees. <br>
#
# People working for Privately-held limited company with 10,000 or more employees are a lot more likely to feel competitive with their peers. Whereas, people working for venture-funded startup (100 to 499 employees) are a lot less likely to feel competitive with their peers.

# %% [markdown]
# ### Q8: Does being competitive against peers affect the job satisfaction?

# %%
df = surveyFiltered.dropna(subset= ['JobSatisfaction'], axis=0)
X = df[['CompetePeers_bin']]
y = df['JobSatisfaction']

X2 = sm.add_constant(X.to_numpy())
lm_model = sm.OLS(y, X2).fit()
print(lm_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        JobSatisfaction   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     9.850
# Date:                Tue, 08 Dec 2020   Prob (F-statistic):            0.00172
# Time:                        01:07:45   Log-Likelihood:                -4657.5
# No. Observations:                2172   AIC:                             9319.
# Df Residuals:                    2170   BIC:                             9330.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.3481      0.063    117.021      0.000       7.225       7.471
# x1            -0.2783      0.089     -3.138      0.002      -0.452      -0.104
# ==============================================================================
# Omnibus:                      251.464   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              344.796
# Skew:                          -0.916   Prob(JB):                     1.34e-75
# Kurtosis:                       3.671   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Of course job satisfaction will not be solely affected by whether you feel competitive against peers or not (the R-square is only 0.005). However, based on the simple linear regression model above, feeling competitive against peers lowers the job satisfaction by 0.28 and the effect is statistically significant (p-value < 0.002). As such, holding other factors constant, feeling less competitive against peers would most likely improve your job satisfaction a bit.

# %% [markdown]
# # Evaluate the Results

# %% [markdown]
# - <b>Does gender matter?</b><br>
#     - The p-value for the Chi-Square Test for Independence = 0.16<br>
#       Not able to reject the null hypothesis that gender and competitiveness are independent<br><br>
#
# - <b>Does race matter?</b><br>
#     - The p-value for the Chi-Square Test for Independence = 0.01<br>
#       Reject the null hypothesis and conclude that there is some relationship between race and competitiveness<br><br>
#
#     - White or of European descent tend not to compete with peers<br>
#     - South Asians do tend to compete with peers<br><br>
#
# - <b>Do the years of coding experience on the job matter?</b>
#     - The p-value for the Chi-Square Test for Independence = 0.00<br>
#       Reject the null hypothesis and conclude that there is some relationship between years of coding experience on the job and competitiveness<br><br>
#
#     - People with less than 5 years of coding experience tend to feel a lot more competitive<br>
#
#     - People with 10–15 years of experience are also more competitive<br>
#
#     - People with more than 20 years of experience are a lot less competitive with their peers<br><br>
#
# - <b>Does the type of developer matter?</b><br>
#     - The p-value for the Chi-Square Test for Independence = 0.08<br><br>
#
#     - DevOps specialists tend to feel more competitive<br>
#     - Embedded applications/devices developers and graphics programming developers tend to feel less competitive<br><br>
#
# - <b>Does the size of the company people work for matter?</b><br>
#     - The p-value for the Chi-Square Test for Independence = 0.46<br>
#       Not able to reject the null hypothesis that the size of the company and competitiveness are independent.<br><br>
#
# - <b>Does the type of the company people work for matter?</b><br>
#     - The p-value for the Chi-Square Test for Independence = 0.13<br>
#       Not able to reject the null hypothesis that the type of the company and competitiveness are independent.<br><br>
#
# - <b>What about different types of companies with different sizes? Does it matter?</b><br>
#     - The p-value for the Chi-Square Test for Independence = 0.04<br>
#       Reject the null hypothesis and conclude that there is some relationship between different types of companies with different sizes and competitiveness.<br><br>
#
#     - People working for privately-held limited companies with 10,000 or more employees were a lot more likely to feel competitive with their peers<br>
#
#     - People working for venture-funded startups (100 to 499 employees) were a lot less competitive<br><br>
#
# - <b>Are competitive programmers tend to be satisfied with their jobs or not?</b><br>
#     - Feeling competitive with peers lowers job satisfaction by 0.28 and the effect is statistically significant (p-value < 0.002)
